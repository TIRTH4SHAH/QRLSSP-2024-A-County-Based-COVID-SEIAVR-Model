# %% [markdown]
# # Part 2: Minimal ODEs/SIR Models in Python
#
# This notebook briefly introduces numerically solving ODEs in Python, using the example of basic SIR models.

# %%
#First load some libraries

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.integrate import solve_ivp

# %%
from sympy import symbols, solve, Matrix

# Define the symbols
S, E, I, A, V, R = symbols('S E I A V R')

# Define parameters
#mu, beta, gamma, N = symbols('mu beta gamma N')
phi, alpha, gamma_I, gamma_A, nu, b_i, sigma, mu, lambda_I, lambda_A, beta, gamma_VI, gamma_VA, theta, mu_c = symbols('phi alpha gamma_I gamma_A nu b_i sigma mu lambda_I lambda_A beta gamma_VI gamma_VA theta mu_c')

# Define the system of equations
dSdt = -gamma_I*S*I - gamma_A*S*A - nu*b_i*S + theta - mu*S
dEdt = gamma_I*S*I + gamma_A*S*A + gamma_VI*V*I + gamma_VA*V*A - beta*E - mu*E
dIdt = (1-sigma)*beta*E - lambda_I*I - mu_c*I - mu*I
dAdt = sigma*beta*E - lambda_A*A - mu*A
dVdt = nu*b_i*S - gamma_VI*V*I - gamma_VA*V*A - phi*V - mu*V
dRdt = lambda_A*A + lambda_I*I + phi*V - mu*R

# Define equilibrium points
equilibrium_points = solve([dSdt, dEdt, dIdt, dAdt, dVdt, dRdt], (S, E, I, A, V, R))

# Display equilibrium points
print("Equilibrium Points:")
for eq_point in equilibrium_points:
    print(eq_point)

# Define Jacobian matrix
J = Matrix([[dSdt.diff(S), dSdt.diff(E), dSdt.diff(I), dSdt.diff(A), dSdt.diff(V), dSdt.diff(R)],
            [dEdt.diff(S), dEdt.diff(E), dEdt.diff(I), dEdt.diff(A), dEdt.diff(V), dEdt.diff(R)],
            [dIdt.diff(S), dIdt.diff(E), dIdt.diff(I), dIdt.diff(A), dIdt.diff(V), dIdt.diff(R)],
            [dAdt.diff(S), dAdt.diff(E), dAdt.diff(I), dAdt.diff(A), dAdt.diff(V), dAdt.diff(R)],
            [dVdt.diff(S), dVdt.diff(E), dVdt.diff(I), dVdt.diff(A), dVdt.diff(V), dVdt.diff(R)],
            [dRdt.diff(S), dRdt.diff(E), dRdt.diff(I), dRdt.diff(A), dRdt.diff(V), dRdt.diff(R)]])

# Display Jacobian matrix
print("\nJacobian Matrix:")
print(J)

# Evaluate Jacobian at equilibrium points and find eigenvalues
for eq_point in equilibrium_points:
    J_eq = J.subs({S: eq_point[0], E: eq_point[1], I: eq_point[2], A: eq_point[3], V: eq_point[4], R: eq_point[5]})
    eigenvalues = J_eq.eigenvals()
    print("\nEquilibrium Point:", eq_point)
    print("Eigenvalues:", eigenvalues)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-64cffb07ffa9> in <cell line: 19>()
#      17
#      18 # Define equilibrium points
# ---> 19 equilibrium_points = solve([dSdt, dEdt, dIdt, dAdt, dVdt, dRdt], (S, E, I, A, V, R))
#      20
#      21 # Display equilibrium points
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1145             solution = _solve(f[0], *symbols, **flags)
#    1146     else:
# -> 1147         linear, solution = _solve_system(f, symbols, **flags)
#    1148     assert type(solution) is list
#    1149     assert not solution or type(solution[0]) is dict, solution
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/solvers.py in _solve_system(exprs, symbols, **flags)
#    1861             else:
#    1862                 try:
# -> 1863                     result = solve_poly_system(polys, *symbols)
#    1864                     if result:
#    1865                         solved_syms = symbols
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/polysys.py in solve_poly_system(seq, strict, *gens, **args)
#      76                 pass
#      77
# ---> 78     return solve_generic(polys, opt, strict=strict)
#      79
#      80
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/polysys.py in solve_generic(polys, opt, strict)
#     331
#     332     try:
# --> 333         result = _solve_reduced_system(polys, opt.gens, entry=True)
#     334     except CoercionFailed:
#     335         raise NotImplementedError
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/polysys.py in _solve_reduced_system(system, gens, entry)
#     271             return [(zero,) for zero in zeros]
#     272
# --> 273         basis = groebner(system, gens, polys=True)
#     274
#     275         if len(basis) == 1 and basis[0].is_ground:
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/polytools.py in groebner(F, *gens, **args)
#    7013
#    7014     """
# -> 7015     return GroebnerBasis(F, *gens, **args)
#    7016
#    7017
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/polytools.py in __new__(cls, F, *gens, **args)
#    7052         polys = [ring.from_dict(poly.rep.to_dict()) for poly in polys if poly]
#    7053
# -> 7054         G = _groebner(polys, ring, method=opt.method)
#    7055         G = [Poly._from_dict(g, opt) for g in G]
#    7056
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/groebnertools.py in groebner(seq, ring, method)
#      41             seq = [ s.set_ring(ring) for s in seq ]
#      42
# ---> 43     G = _groebner(seq, ring)
#      44
#      45     if orig is not None:
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/groebnertools.py in _buchberger(f, ring)
#     236         # ordering divisors is on average more efficient [Cox] page 111
#     237         G1 = sorted(G, key=lambda g: order(f[g].LM))
# --> 238         ht = normal(h, G1)
#     239
#     240         if ht:
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/groebnertools.py in normal(g, J)
#     102
#     103     def normal(g, J):
# --> 104         h = g.rem([ f[j] for j in J ])
#     105
#     106         if not h:
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/rings.py in rem(self, G)
#    1510                     for mg, cg in g.iterterms():
#    1511                         m1 = monomial_mul(mg, m)
# -> 1512                         c1 = get(m1, zero) - c*cg
#    1513                         if not c1:
#    1514                             del f[m1]
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/fields.py in __sub__(f, g)
#     449                 return f.new(f.numer - g.numer, f.denom)
#     450             else:
# --> 451                 return f.new(f.numer*g.denom - f.denom*g.numer, f.denom*g.denom)
#     452         elif isinstance(g, field.ring.dtype):
#     453             return f.new(f.numer - f.denom*g, f.denom)
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/fields.py in new(f, numer, denom)
#     299         return f.__class__(numer, denom)
#     300     def new(f, numer, denom):
# --> 301         return f.raw_new(*numer.cancel(denom))
#     302
#     303     def to_poly(f):
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/rings.py in cancel(self, g)
#    2240
#    2241         if not (domain.is_Field and domain.has_assoc_Ring):
# -> 2242             _, p, q = f.cofactors(g)
#    2243         else:
#    2244             new_ring = ring.clone(domain=domain.get_ring())
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/rings.py in cofactors(f, g)
#    2156
#    2157         J, (f, g) = f.deflate(g)
# -> 2158         h, cff, cfg = f._gcd(g)
#    2159
#    2160         return (h.inflate(J), cff.inflate(J), cfg.inflate(J))
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/rings.py in _gcd(f, g)
#    2189             return f._gcd_QQ(g)
#    2190         elif ring.domain.is_ZZ:
# -> 2191             return f._gcd_ZZ(g)
#    2192         else: # TODO: don't use dense representation (port PRS algorithms)
#    2193             return ring.dmp_inner_gcd(f, g)
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/rings.py in _gcd_ZZ(f, g)
#    2194
#    2195     def _gcd_ZZ(f, g):
# -> 2196         return heugcd(f, g)
#    2197
#    2198     def _gcd_QQ(self, g):
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/heuristicgcd.py in heugcd(f, g)
#      78                 h, cff, cfg = domain.cofactors(ff, gg)
#      79             else:
# ---> 80                 h, cff, cfg = heugcd(ff, gg)
#      81
#      82             h = _gcd_interpolate(h, x, ring)
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/heuristicgcd.py in heugcd(f, g)
#      78                 h, cff, cfg = domain.cofactors(ff, gg)
#      79             else:
# ---> 80                 h, cff, cfg = heugcd(ff, gg)
#      81
#      82             h = _gcd_interpolate(h, x, ring)
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/heuristicgcd.py in heugcd(f, g)
#      78                 h, cff, cfg = domain.cofactors(ff, gg)
#      79             else:
# ---> 80                 h, cff, cfg = heugcd(ff, gg)
#      81
#      82             h = _gcd_interpolate(h, x, ring)
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/heuristicgcd.py in heugcd(f, g)
#      78                 h, cff, cfg = domain.cofactors(ff, gg)
#      79             else:
# ---> 80                 h, cff, cfg = heugcd(ff, gg)
#      81
#      82             h = _gcd_interpolate(h, x, ring)
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/heuristicgcd.py in heugcd(f, g)
#      78                 h, cff, cfg = domain.cofactors(ff, gg)
#      79             else:
# ---> 80                 h, cff, cfg = heugcd(ff, gg)
#      81
#      82             h = _gcd_interpolate(h, x, ring)
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/heuristicgcd.py in heugcd(f, g)
#      78                 h, cff, cfg = domain.cofactors(ff, gg)
#      79             else:
# ---> 80                 h, cff, cfg = heugcd(ff, gg)
#      81
#      82             h = _gcd_interpolate(h, x, ring)
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/heuristicgcd.py in heugcd(f, g)
#      78                 h, cff, cfg = domain.cofactors(ff, gg)
#      79             else:
# ---> 80                 h, cff, cfg = heugcd(ff, gg)
#      81
#      82             h = _gcd_interpolate(h, x, ring)
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/heuristicgcd.py in heugcd(f, g)
#      78                 h, cff, cfg = domain.cofactors(ff, gg)
#      79             else:
# ---> 80                 h, cff, cfg = heugcd(ff, gg)
#      81
#      82             h = _gcd_interpolate(h, x, ring)
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/heuristicgcd.py in heugcd(f, g)
#      78                 h, cff, cfg = domain.cofactors(ff, gg)
#      79             else:
# ---> 80                 h, cff, cfg = heugcd(ff, gg)
#      81
#      82             h = _gcd_interpolate(h, x, ring)
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/heuristicgcd.py in heugcd(f, g)
#      59     domain = ring.domain
#      60
# ---> 61     gcd, f, g = f.extract_ground(g)
#      62
#      63     f_norm = f.max_norm()
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/rings.py in extract_ground(self, g)
#    2059         gcd = f.ring.domain.gcd(fc, gc)
#    2060
# -> 2061         f = f.quo_ground(gcd)
#    2062         g = g.quo_ground(gcd)
#    2063
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/rings.py in quo_ground(f, x)
#    2013             terms = [ (monom, quo(coeff, x)) for monom, coeff in f.iterterms() ]
#    2014         else:
# -> 2015             terms = [ (monom, coeff // x) for monom, coeff in f.iterterms() if not (coeff % x) ]
#    2016
#    2017         return f.new(terms)
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/rings.py in <listcomp>(.0)
#    2013             terms = [ (monom, quo(coeff, x)) for monom, coeff in f.iterterms() ]
#    2014         else:
# -> 2015             terms = [ (monom, coeff // x) for monom, coeff in f.iterterms() if not (coeff % x) ]
#    2016
#    2017         return f.new(terms)
#
# KeyboardInterrupt:

# %%
from scipy.integrate import solve_ivp

# %% [markdown]
# Prof

# %%
from sympy import symbols, Matrix

# Define symbols
S, E, I, A, V, R = symbols('S E I A V R')
S0, phi, alpha, gamma_I, gamma_A, gamma_VI, gamma_VA, nu, b_i, sigma, mu, lambda_I, lambda_A, beta, theta, omega = symbols('S0 phi alpha gamma_I gamma_A gamma_VI gamma_VA nu b_i sigma mu lambda_I lambda_A beta theta omega')

# Define the system of equations
dSdt = - gamma_I * S * I - gamma_A * S * A - nu * b_i * S + theta #- mu*S
dEdt = gamma_I * S * I + gamma_A * S * A + gamma_VI * V * I + gamma_VA * V * A  - beta * E #- mu*E
dIdt = (1 - sigma) * beta * E - mu_c * I - lambda_I * I #- mu*I
dAdt = sigma * beta * E - lambda_A * A #- mu*A
dVdt = nu * b_i * S -gamma_VI * V * I - gamma_VA * V * A - phi * V #- mu*V
dRdt = lambda_A * A + lambda_I * I + phi * V #- mu*R
dDdt = omega * I

# Define equilibrium points
equilibrium_points = [S0, S0*b_i*nu/phi, 0, 0, 0, 0]

# Display equilibrium points
print("Equilibrium Points:")
for eq_point in equilibrium_points:
    print(eq_point)

# Define Jacobian matrix
J = Matrix([[dSdt.diff(S), dSdt.diff(E), dSdt.diff(I), dSdt.diff(A), dSdt.diff(V), dSdt.diff(R)],
            [dEdt.diff(S), dEdt.diff(E), dEdt.diff(I), dEdt.diff(A), dEdt.diff(V), dEdt.diff(R)],
            [dIdt.diff(S), dIdt.diff(E), dIdt.diff(I), dIdt.diff(A), dIdt.diff(V), dIdt.diff(R)],
            [dAdt.diff(S), dAdt.diff(E), dAdt.diff(I), dAdt.diff(A), dAdt.diff(V), dAdt.diff(R)],
            [dVdt.diff(S), dVdt.diff(E), dVdt.diff(I), dVdt.diff(A), dVdt.diff(V), dVdt.diff(R)],
            [dRdt.diff(S), dRdt.diff(E), dRdt.diff(I), dRdt.diff(A), dRdt.diff(V), dRdt.diff(R)]])

# Display Jacobian matrix
print("\nJacobian Matrix:")
print(J)

# Evaluate Jacobian at equilibrium points and find eigenvalues
for eq_point in equilibrium_points:
    # Substitute equilibrium points into the Jacobian matrix
    J_eq = J.subs({S: eq_point, E: 0, I: 0, A: 0, V: 0, R: 0})
    eigenvalues = J_eq.eigenvals()
    print("\nEquilibrium Point:", eq_point)
    print("Eigenvalues:", eigenvalues)
# Out:
# Equilibrium Points:
# S0
# S0*b_i*nu/phi
# 0
# 0
# 0
# 0
#
# Jacobian Matrix:
# Matrix([[-A*gamma_A - I*gamma_I - b_i*nu, 0, -S*gamma_I, -S*gamma_A, 0, 0], [A*gamma_A + I*gamma_I, -beta, S*gamma_I + V*gamma_VI, S*gamma_A + V*gamma_VA, A*gamma_VA + I*gamma_VI, 0], [0, beta*(1 - sigma), -lambda_I - mu_c, 0, 0, 0], [0, beta*sigma, 0, -lambda_A, 0, 0], [b_i*nu, 0, -V*gamma_VI, -V*gamma_VA, -A*gamma_VA - I*gamma_VI - phi, 0], [0, 0, lambda_I, lambda_A, phi, 0]])
#
# Equilibrium Point: S0
# Eigenvalues: {-beta/3 - lambda_A/3 - lambda_I/3 - mu_c/3 - (3*S0*beta*gamma_A*sigma - 3*S0*beta*gamma_I*sigma + 3*S0*beta*gamma_I - 3*beta*lambda_A - 3*beta*lambda_I - 3*beta*mu_c - 3*lambda_A*lambda_I - 3*lambda_A*mu_c + (beta + lambda_A + lambda_I + mu_c)**2)/(3*(-27*S0*beta*gamma_A*lambda_I*sigma/2 - 27*S0*beta*gamma_A*mu_c*sigma/2 + 27*S0*beta*gamma_I*lambda_A*sigma/2 - 27*S0*beta*gamma_I*lambda_A/2 + 27*beta*lambda_A*lambda_I/2 + 27*beta*lambda_A*mu_c/2 + sqrt((-27*S0*beta*gamma_A*lambda_I*sigma - 27*S0*beta*gamma_A*mu_c*sigma + 27*S0*beta*gamma_I*lambda_A*sigma - 27*S0*beta*gamma_I*lambda_A + 27*beta*lambda_A*lambda_I + 27*beta*lambda_A*mu_c + 2*(beta + lambda_A + lambda_I + mu_c)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu_c)*(-S0*beta*gamma_A*sigma + S0*beta*gamma_I*sigma - S0*beta*gamma_I + beta*lambda_A + beta*lambda_I + beta*mu_c + lambda_A*lambda_I + lambda_A*mu_c))**2 - 4*(3*S0*beta*gamma_A*sigma - 3*S0*beta*gamma_I*sigma + 3*S0*beta*gamma_I - 3*beta*lambda_A - 3*beta*lambda_I - 3*beta*mu_c - 3*lambda_A*lambda_I - 3*lambda_A*mu_c + (beta + lambda_A + lambda_I + mu_c)**2)**3)/2 + (beta + lambda_A + lambda_I + mu_c)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu_c)*(-S0*beta*gamma_A*sigma + S0*beta*gamma_I*sigma - S0*beta*gamma_I + beta*lambda_A + beta*lambda_I + beta*mu_c + lambda_A*lambda_I + lambda_A*mu_c)/2)**(1/3)) - (-27*S0*beta*gamma_A*lambda_I*sigma/2 - 27*S0*beta*gamma_A*mu_c*sigma/2 + 27*S0*beta*gamma_I*lambda_A*sigma/2 - 27*S0*beta*gamma_I*lambda_A/2 + 27*beta*lambda_A*lambda_I/2 + 27*beta*lambda_A*mu_c/2 + sqrt((-27*S0*beta*gamma_A*lambda_I*sigma - 27*S0*beta*gamma_A*mu_c*sigma + 27*S0*beta*gamma_I*lambda_A*sigma - 27*S0*beta*gamma_I*lambda_A + 27*beta*lambda_A*lambda_I + 27*beta*lambda_A*mu_c + 2*(beta + lambda_A + lambda_I + mu_c)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu_c)*(-S0*beta*gamma_A*sigma + S0*beta*gamma_I*sigma - S0*beta*gamma_I + beta*lambda_A + beta*lambda_I + beta*mu_c + lambda_A*lambda_I + lambda_A*mu_c))**2 - 4*(3*S0*beta*gamma_A*sigma - 3*S0*beta*gamma_I*sigma + 3*S0*beta*gamma_I - 3*beta*lambda_A - 3*beta*lambda_I - 3*beta*mu_c - 3*lambda_A*lambda_I - 3*lambda_A*mu_c + (beta + lambda_A + lambda_I + mu_c)**2)**3)/2 + (beta + lambda_A + lambda_I + mu_c)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu_c)*(-S0*beta*gamma_A*sigma + S0*beta*gamma_I*sigma - S0*beta*gamma_I + beta*lambda_A + beta*lambda_I + beta*mu_c + lambda_A*lambda_I + lambda_A*mu_c)/2)**(1/3)/3: 1, -beta/3 - lambda_A/3 - lambda_I/3 - mu_c/3 - (3*S0*beta*gamma_A*sigma - 3*S0*beta*gamma_I*sigma + 3*S0*beta*gamma_I - 3*beta*lambda_A - 3*beta*lambda_I - 3*beta*mu_c - 3*lambda_A*lambda_I - 3*lambda_A*mu_c + (beta + lambda_A + lambda_I + mu_c)**2)/(3*(-1/2 + sqrt(3)*I/2)*(-27*S0*beta*gamma_A*lambda_I*sigma/2 - 27*S0*beta*gamma_A*mu_c*sigma/2 + 27*S0*beta*gamma_I*lambda_A*sigma/2 - 27*S0*beta*gamma_I*lambda_A/2 + 27*beta*lambda_A*lambda_I/2 + 27*beta*lambda_A*mu_c/2 + sqrt((-27*S0*beta*gamma_A*lambda_I*sigma - 27*S0*beta*gamma_A*mu_c*sigma + 27*S0*beta*gamma_I*lambda_A*sigma - 27*S0*beta*gamma_I*lambda_A + 27*beta*lambda_A*lambda_I + 27*beta*lambda_A*mu_c + 2*(beta + lambda_A + lambda_I + mu_c)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu_c)*(-S0*beta*gamma_A*sigma + S0*beta*gamma_I*sigma - S0*beta*gamma_I + beta*lambda_A + beta*lambda_I + beta*mu_c + lambda_A*lambda_I + lambda_A*mu_c))**2 - 4*(3*S0*beta*gamma_A*sigma - 3*S0*beta*gamma_I*sigma + 3*S0*beta*gamma_I - 3*beta*lambda_A - 3*beta*lambda_I - 3*beta*mu_c - 3*lambda_A*lambda_I - 3*lambda_A*mu_c + (beta + lambda_A + lambda_I + mu_c)**2)**3)/2 + (beta + lambda_A + lambda_I + mu_c)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu_c)*(-S0*beta*gamma_A*sigma + S0*beta*gamma_I*sigma - S0*beta*gamma_I + beta*lambda_A + beta*lambda_I + beta*mu_c + lambda_A*lambda_I + lambda_A*mu_c)/2)**(1/3)) - (-1/2 + sqrt(3)*I/2)*(-27*S0*beta*gamma_A*lambda_I*sigma/2 - 27*S0*beta*gamma_A*mu_c*sigma/2 + 27*S0*beta*gamma_I*lambda_A*sigma/2 - 27*S0*beta*gamma_I*lambda_A/2 + 27*beta*lambda_A*lambd ...
#
# Equilibrium Point: S0*b_i*nu/phi
# Eigenvalues: {-beta/3 - lambda_A/3 - lambda_I/3 - mu_c/3 - ((beta + lambda_A + lambda_I + mu_c)**2 - 3*(-S0*b_i*beta*gamma_A*nu*sigma + S0*b_i*beta*gamma_I*nu*sigma - S0*b_i*beta*gamma_I*nu + beta*lambda_A*phi + beta*lambda_I*phi + beta*mu_c*phi + lambda_A*lambda_I*phi + lambda_A*mu_c*phi)/phi)/(3*(sqrt(-4*((beta + lambda_A + lambda_I + mu_c)**2 - 3*(-S0*b_i*beta*gamma_A*nu*sigma + S0*b_i*beta*gamma_I*nu*sigma - S0*b_i*beta*gamma_I*nu + beta*lambda_A*phi + beta*lambda_I*phi + beta*mu_c*phi + lambda_A*lambda_I*phi + lambda_A*mu_c*phi)/phi)**3 + (2*(beta + lambda_A + lambda_I + mu_c)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu_c)*(-S0*b_i*beta*gamma_A*nu*sigma + S0*b_i*beta*gamma_I*nu*sigma - S0*b_i*beta*gamma_I*nu + beta*lambda_A*phi + beta*lambda_I*phi + beta*mu_c*phi + lambda_A*lambda_I*phi + lambda_A*mu_c*phi)/phi + 27*(-S0*b_i*beta*gamma_A*lambda_I*nu*sigma - S0*b_i*beta*gamma_A*mu_c*nu*sigma + S0*b_i*beta*gamma_I*lambda_A*nu*sigma - S0*b_i*beta*gamma_I*lambda_A*nu + beta*lambda_A*lambda_I*phi + beta*lambda_A*mu_c*phi)/phi)**2)/2 + (beta + lambda_A + lambda_I + mu_c)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu_c)*(-S0*b_i*beta*gamma_A*nu*sigma + S0*b_i*beta*gamma_I*nu*sigma - S0*b_i*beta*gamma_I*nu + beta*lambda_A*phi + beta*lambda_I*phi + beta*mu_c*phi + lambda_A*lambda_I*phi + lambda_A*mu_c*phi)/(2*phi) + 27*(-S0*b_i*beta*gamma_A*lambda_I*nu*sigma - S0*b_i*beta*gamma_A*mu_c*nu*sigma + S0*b_i*beta*gamma_I*lambda_A*nu*sigma - S0*b_i*beta*gamma_I*lambda_A*nu + beta*lambda_A*lambda_I*phi + beta*lambda_A*mu_c*phi)/(2*phi))**(1/3)) - (sqrt(-4*((beta + lambda_A + lambda_I + mu_c)**2 - 3*(-S0*b_i*beta*gamma_A*nu*sigma + S0*b_i*beta*gamma_I*nu*sigma - S0*b_i*beta*gamma_I*nu + beta*lambda_A*phi + beta*lambda_I*phi + beta*mu_c*phi + lambda_A*lambda_I*phi + lambda_A*mu_c*phi)/phi)**3 + (2*(beta + lambda_A + lambda_I + mu_c)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu_c)*(-S0*b_i*beta*gamma_A*nu*sigma + S0*b_i*beta*gamma_I*nu*sigma - S0*b_i*beta*gamma_I*nu + beta*lambda_A*phi + beta*lambda_I*phi + beta*mu_c*phi + lambda_A*lambda_I*phi + lambda_A*mu_c*phi)/phi + 27*(-S0*b_i*beta*gamma_A*lambda_I*nu*sigma - S0*b_i*beta*gamma_A*mu_c*nu*sigma + S0*b_i*beta*gamma_I*lambda_A*nu*sigma - S0*b_i*beta*gamma_I*lambda_A*nu + beta*lambda_A*lambda_I*phi + beta*lambda_A*mu_c*phi)/phi)**2)/2 + (beta + lambda_A + lambda_I + mu_c)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu_c)*(-S0*b_i*beta*gamma_A*nu*sigma + S0*b_i*beta*gamma_I*nu*sigma - S0*b_i*beta*gamma_I*nu + beta*lambda_A*phi + beta*lambda_I*phi + beta*mu_c*phi + lambda_A*lambda_I*phi + lambda_A*mu_c*phi)/(2*phi) + 27*(-S0*b_i*beta*gamma_A*lambda_I*nu*sigma - S0*b_i*beta*gamma_A*mu_c*nu*sigma + S0*b_i*beta*gamma_I*lambda_A*nu*sigma - S0*b_i*beta*gamma_I*lambda_A*nu + beta*lambda_A*lambda_I*phi + beta*lambda_A*mu_c*phi)/(2*phi))**(1/3)/3: 1, -beta/3 - lambda_A/3 - lambda_I/3 - mu_c/3 - ((beta + lambda_A + lambda_I + mu_c)**2 - 3*(-S0*b_i*beta*gamma_A*nu*sigma + S0*b_i*beta*gamma_I*nu*sigma - S0*b_i*beta*gamma_I*nu + beta*lambda_A*phi + beta*lambda_I*phi + beta*mu_c*phi + lambda_A*lambda_I*phi + lambda_A*mu_c*phi)/phi)/(3*(-1/2 + sqrt(3)*I/2)*(sqrt(-4*((beta + lambda_A + lambda_I + mu_c)**2 - 3*(-S0*b_i*beta*gamma_A*nu*sigma + S0*b_i*beta*gamma_I*nu*sigma - S0*b_i*beta*gamma_I*nu + beta*lambda_A*phi + beta*lambda_I*phi + beta*mu_c*phi + lambda_A*lambda_I*phi + lambda_A*mu_c*phi)/phi)**3 + (2*(beta + lambda_A + lambda_I + mu_c)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu_c)*(-S0*b_i*beta*gamma_A*nu*sigma + S0*b_i*beta*gamma_I*nu*sigma - S0*b_i*beta*gamma_I*nu + beta*lambda_A*phi + beta*lambda_I*phi + beta*mu_c*phi + lambda_A*lambda_I*phi + lambda_A*mu_c*phi)/phi + 27*(-S0*b_i*beta*gamma_A*lambda_I*nu*sigma - S0*b_i*beta*gamma_A*mu_c*nu*sigma + S0*b_i*beta*gamma_I*lambda_A*nu*sigma - S0*b_i*beta*gamma_I*lambda_A*nu + beta*lambda_A*lambda_I*phi + beta*lambda_A*mu_c*phi)/phi)**2)/2 + (beta + lambda_A + lambda_I + mu_c)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu_c)*(-S0*b_i*beta*gamma_A*nu* ...
#
# Equilibrium Point: 0
# Eigenvalues: {-b_i*nu: 1, -beta: 1, -lambda_I - mu_c: 1, -lambda_A: 1, -phi: 1, 0: 1}
#
# Equilibrium Point: 0
# Eigenvalues: {-b_i*nu: 1, -beta: 1, -lambda_I - mu_c: 1, -lambda_A: 1, -phi: 1, 0: 1}
#
# Equilibrium Point: 0
# Eigenvalues: {-b_i*nu: 1, -beta: 1, -lambda_I - mu_c: 1, -lambda_A: 1, -phi: 1, 0: 1}
#
# Equilibrium Point: 0
# Eigenvalues: {-b_i*nu: 1, -beta: 1, -lambda_I - mu_c: 1, -lambda_A: 1, -phi: 1, 0: 1}

# %%
from sympy import symbols, Matrix

# Define symbols
beta, gamma_I, gamma_A, S, sigma, mu, lambda_I, lambda_A = symbols('beta gamma_I gamma_A S sigma mu lambda_I lambda_A')

# Define the matrix J
J = Matrix([
    [-beta, gamma_I*S, gamma_A*S],
    [(1-sigma)*beta, -(mu+lambda_I), 0],
    [sigma*beta, 0, -lambda_A]
])

# Find eigenvalues symbolically
eigenvalues = J.eigenvals()

# Print eigenvalues (symbolic form)
print('Eigenvalues (symbolic):', eigenvalues)
# Out:
# Eigenvalues (symbolic): {-beta/3 - lambda_A/3 - lambda_I/3 - mu/3 - (3*S*beta*gamma_A*sigma - 3*S*beta*gamma_I*sigma + 3*S*beta*gamma_I - 3*beta*lambda_A - 3*beta*lambda_I - 3*beta*mu - 3*lambda_A*lambda_I - 3*lambda_A*mu + (beta + lambda_A + lambda_I + mu)**2)/(3*(-27*S*beta*gamma_A*lambda_I*sigma/2 - 27*S*beta*gamma_A*mu*sigma/2 + 27*S*beta*gamma_I*lambda_A*sigma/2 - 27*S*beta*gamma_I*lambda_A/2 + 27*beta*lambda_A*lambda_I/2 + 27*beta*lambda_A*mu/2 + sqrt((-27*S*beta*gamma_A*lambda_I*sigma - 27*S*beta*gamma_A*mu*sigma + 27*S*beta*gamma_I*lambda_A*sigma - 27*S*beta*gamma_I*lambda_A + 27*beta*lambda_A*lambda_I + 27*beta*lambda_A*mu + 2*(beta + lambda_A + lambda_I + mu)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu)*(-S*beta*gamma_A*sigma + S*beta*gamma_I*sigma - S*beta*gamma_I + beta*lambda_A + beta*lambda_I + beta*mu + lambda_A*lambda_I + lambda_A*mu))**2 - 4*(3*S*beta*gamma_A*sigma - 3*S*beta*gamma_I*sigma + 3*S*beta*gamma_I - 3*beta*lambda_A - 3*beta*lambda_I - 3*beta*mu - 3*lambda_A*lambda_I - 3*lambda_A*mu + (beta + lambda_A + lambda_I + mu)**2)**3)/2 + (beta + lambda_A + lambda_I + mu)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu)*(-S*beta*gamma_A*sigma + S*beta*gamma_I*sigma - S*beta*gamma_I + beta*lambda_A + beta*lambda_I + beta*mu + lambda_A*lambda_I + lambda_A*mu)/2)**(1/3)) - (-27*S*beta*gamma_A*lambda_I*sigma/2 - 27*S*beta*gamma_A*mu*sigma/2 + 27*S*beta*gamma_I*lambda_A*sigma/2 - 27*S*beta*gamma_I*lambda_A/2 + 27*beta*lambda_A*lambda_I/2 + 27*beta*lambda_A*mu/2 + sqrt((-27*S*beta*gamma_A*lambda_I*sigma - 27*S*beta*gamma_A*mu*sigma + 27*S*beta*gamma_I*lambda_A*sigma - 27*S*beta*gamma_I*lambda_A + 27*beta*lambda_A*lambda_I + 27*beta*lambda_A*mu + 2*(beta + lambda_A + lambda_I + mu)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu)*(-S*beta*gamma_A*sigma + S*beta*gamma_I*sigma - S*beta*gamma_I + beta*lambda_A + beta*lambda_I + beta*mu + lambda_A*lambda_I + lambda_A*mu))**2 - 4*(3*S*beta*gamma_A*sigma - 3*S*beta*gamma_I*sigma + 3*S*beta*gamma_I - 3*beta*lambda_A - 3*beta*lambda_I - 3*beta*mu - 3*lambda_A*lambda_I - 3*lambda_A*mu + (beta + lambda_A + lambda_I + mu)**2)**3)/2 + (beta + lambda_A + lambda_I + mu)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu)*(-S*beta*gamma_A*sigma + S*beta*gamma_I*sigma - S*beta*gamma_I + beta*lambda_A + beta*lambda_I + beta*mu + lambda_A*lambda_I + lambda_A*mu)/2)**(1/3)/3: 1, -beta/3 - lambda_A/3 - lambda_I/3 - mu/3 - (3*S*beta*gamma_A*sigma - 3*S*beta*gamma_I*sigma + 3*S*beta*gamma_I - 3*beta*lambda_A - 3*beta*lambda_I - 3*beta*mu - 3*lambda_A*lambda_I - 3*lambda_A*mu + (beta + lambda_A + lambda_I + mu)**2)/(3*(-1/2 + sqrt(3)*I/2)*(-27*S*beta*gamma_A*lambda_I*sigma/2 - 27*S*beta*gamma_A*mu*sigma/2 + 27*S*beta*gamma_I*lambda_A*sigma/2 - 27*S*beta*gamma_I*lambda_A/2 + 27*beta*lambda_A*lambda_I/2 + 27*beta*lambda_A*mu/2 + sqrt((-27*S*beta*gamma_A*lambda_I*sigma - 27*S*beta*gamma_A*mu*sigma + 27*S*beta*gamma_I*lambda_A*sigma - 27*S*beta*gamma_I*lambda_A + 27*beta*lambda_A*lambda_I + 27*beta*lambda_A*mu + 2*(beta + lambda_A + lambda_I + mu)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu)*(-S*beta*gamma_A*sigma + S*beta*gamma_I*sigma - S*beta*gamma_I + beta*lambda_A + beta*lambda_I + beta*mu + lambda_A*lambda_I + lambda_A*mu))**2 - 4*(3*S*beta*gamma_A*sigma - 3*S*beta*gamma_I*sigma + 3*S*beta*gamma_I - 3*beta*lambda_A - 3*beta*lambda_I - 3*beta*mu - 3*lambda_A*lambda_I - 3*lambda_A*mu + (beta + lambda_A + lambda_I + mu)**2)**3)/2 + (beta + lambda_A + lambda_I + mu)**3 - (9*beta + 9*lambda_A + 9*lambda_I + 9*mu)*(-S*beta*gamma_A*sigma + S*beta*gamma_I*sigma - S*beta*gamma_I + beta*lambda_A + beta*lambda_I + beta*mu + lambda_A*lambda_I + lambda_A*mu)/2)**(1/3)) - (-1/2 + sqrt(3)*I/2)*(-27*S*beta*gamma_A*lambda_I*sigma/2 - 27*S*beta*gamma_A*mu*sigma/2 + 27*S*beta*gamma_I*lambda_A*sigma/2 - 27*S*beta*gamma_I*lambda_A/2 + 27*beta*lambda_A*lambda_I/2 + 27*beta*lambda_A*mu/2 + sqrt((-27*S*beta*gamma_A*lambda_I*sigma - 27*S*beta*gamma_A*mu*sigma + 27*S*beta*gamma_I*lambda_A*sigma - 27*S*beta*gamma_I*la ...

# %%
from sympy import symbols, solve, Matrix

# Define the symbols
S, E, I, A, V, R = symbols('S E I A V R')

# Define parameter values
gamma_I=0.000045 / 6500
nu=0.00982 * 2
b_i=0.553
alpha=0.92
beta=1 / 2.8
phi=1 / 10.17
sigma=0.35
mu=0.00189
lambda_I=1 / 9
lambda_A=1 / 9
N = 2.9 * 1e7
gamma_VI = (1- alpha)*gamma_I
gamma_VA = (1- alpha)*gamma_A

S, E, I, A, V, R = symbols('S E I A V R')
phi, alpha, gamma_I, gamma_A, gamma_VI, gamma_VA, nu, b_i, sigma, mu, lambda_I, lambda_A, beta, theta, omega = symbols('phi alpha gamma_I gamma_A gamma_VI gamma_VA nu b_i sigma mu lambda_I lambda_A beta theta omega')

# Define the system of equations
dSdt = - gamma_I * S * I - gamma_A * S * A - nu * b_i * S + theta - 0.007152*S
dEdt = gamma_I * S * I + gamma_A * S * A + gamma_VI * V * I + gamma_VA * V * A  - beta * E - 0.007152*E
dIdt = (1 - sigma) * beta * E - mu_c * I - lambda_I * I - 0.007152*I
dAdt = sigma * beta * E - lambda_A * A - 0.007152*A
dVdt = nu * b_i * S -gamma_VI * V * I - gamma_VA * V * A - phi * V - 0.007152*V
dRdt = lambda_A * A + lambda_I * I + phi * V - 0.007152*R
dDdt = omega * I

# Define equilibrium points
equilibrium_points = solve([dSdt, dEdt, dIdt, dAdt, dVdt, dRdt], (S, E, I, A, V, R))

# Display equilibrium points
print("Equilibrium Points:")
for eq_point in equilibrium_points:
    print(eq_point)

# Define Jacobian matrix
J = Matrix([[dSdt.diff(S), dSdt.diff(E), dSdt.diff(I), dSdt.diff(A), dSdt.diff(V), dSdt.diff(R)],
            [dEdt.diff(S), dEdt.diff(E), dEdt.diff(I), dEdt.diff(A), dEdt.diff(V), dEdt.diff(R)],
            [dIdt.diff(S), dIdt.diff(E), dIdt.diff(I), dIdt.diff(A), dIdt.diff(V), dIdt.diff(R)],
            [dAdt.diff(S), dAdt.diff(E), dAdt.diff(I), dAdt.diff(A), dAdt.diff(V), dAdt.diff(R)],
            [dVdt.diff(S), dVdt.diff(E), dVdt.diff(I), dVdt.diff(A), dVdt.diff(V), dVdt.diff(R)],
            [dRdt.diff(S), dRdt.diff(E), dRdt.diff(I), dRdt.diff(A), dRdt.diff(V), dRdt.diff(R)]])

# Display Jacobian matrix
print("\nJacobian Matrix:")
print(J)

# Evaluate Jacobian at equilibrium points and find eigenvalues
for eq_point in equilibrium_points:
    J_eq = J.subs({S: eq_point[0], E: eq_point[1], I: eq_point[2], A: eq_point[3], V: eq_point[4], R: eq_point[5]})
    eigenvalues = J_eq.eigenvals()
    print("\nEquilibrium Point:", eq_point)
    print("Eigenvalues:", eigenvalues)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-022b2fcba8dd> in <cell line: 34>()
#      32
#      33 # Define equilibrium points
# ---> 34 equilibrium_points = solve([dSdt, dEdt, dIdt, dAdt, dVdt, dRdt], (S, E, I, A, V, R))
#      35
#      36 # Display equilibrium points
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1145             solution = _solve(f[0], *symbols, **flags)
#    1146     else:
# -> 1147         linear, solution = _solve_system(f, symbols, **flags)
#    1148     assert type(solution) is list
#    1149     assert not solution or type(solution[0]) is dict, solution
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/solvers.py in _solve_system(exprs, symbols, **flags)
#    1861             else:
#    1862                 try:
# -> 1863                     result = solve_poly_system(polys, *symbols)
#    1864                     if result:
#    1865                         solved_syms = symbols
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/polysys.py in solve_poly_system(seq, strict, *gens, **args)
#      76                 pass
#      77
# ---> 78     return solve_generic(polys, opt, strict=strict)
#      79
#      80
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/polysys.py in solve_generic(polys, opt, strict)
#     331
#     332     try:
# --> 333         result = _solve_reduced_system(polys, opt.gens, entry=True)
#     334     except CoercionFailed:
#     335         raise NotImplementedError
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/polysys.py in _solve_reduced_system(system, gens, entry)
#     271             return [(zero,) for zero in zeros]
#     272
# --> 273         basis = groebner(system, gens, polys=True)
#     274
#     275         if len(basis) == 1 and basis[0].is_ground:
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/polytools.py in groebner(F, *gens, **args)
#    7013
#    7014     """
# -> 7015     return GroebnerBasis(F, *gens, **args)
#    7016
#    7017
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/polytools.py in __new__(cls, F, *gens, **args)
#    7052         polys = [ring.from_dict(poly.rep.to_dict()) for poly in polys if poly]
#    7053
# -> 7054         G = _groebner(polys, ring, method=opt.method)
#    7055         G = [Poly._from_dict(g, opt) for g in G]
#    7056
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/groebnertools.py in groebner(seq, ring, method)
#      41             seq = [ s.set_ring(ring) for s in seq ]
#      42
# ---> 43     G = _groebner(seq, ring)
#      44
#      45     if orig is not None:
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/groebnertools.py in _buchberger(f, ring)
#     236         # ordering divisors is on average more efficient [Cox] page 111
#     237         G1 = sorted(G, key=lambda g: order(f[g].LM))
# --> 238         ht = normal(h, G1)
#     239
#     240         if ht:
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/groebnertools.py in normal(g, J)
#     102
#     103     def normal(g, J):
# --> 104         h = g.rem([ f[j] for j in J ])
#     105
#     106         if not h:
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/rings.py in rem(self, G)
#    1510                     for mg, cg in g.iterterms():
#    1511                         m1 = monomial_mul(mg, m)
# -> 1512                         c1 = get(m1, zero) - c*cg
#    1513                         if not c1:
#    1514                             del f[m1]
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/fields.py in __mul__(f, g)
#     495             return field.zero
#     496         elif isinstance(g, field.dtype):
# --> 497             return f.new(f.numer*g.numer, f.denom*g.denom)
#     498         elif isinstance(g, field.ring.dtype):
#     499             return f.new(f.numer*g, f.denom)
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/fields.py in new(f, numer, denom)
#     299         return f.__class__(numer, denom)
#     300     def new(f, numer, denom):
# --> 301         return f.raw_new(*numer.cancel(denom))
#     302
#     303     def to_poly(f):
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/rings.py in cancel(self, g)
#    2240
#    2241         if not (domain.is_Field and domain.has_assoc_Ring):
# -> 2242             _, p, q = f.cofactors(g)
#    2243         else:
#    2244             new_ring = ring.clone(domain=domain.get_ring())
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/rings.py in cofactors(f, g)
#    2156
#    2157         J, (f, g) = f.deflate(g)
# -> 2158         h, cff, cfg = f._gcd(g)
#    2159
#    2160         return (h.inflate(J), cff.inflate(J), cfg.inflate(J))
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/rings.py in _gcd(f, g)
#    2189             return f._gcd_QQ(g)
#    2190         elif ring.domain.is_ZZ:
# -> 2191             return f._gcd_ZZ(g)
#    2192         else: # TODO: don't use dense representation (port PRS algorithms)
#    2193             return ring.dmp_inner_gcd(f, g)
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/rings.py in _gcd_ZZ(f, g)
#    2194
#    2195     def _gcd_ZZ(f, g):
# -> 2196         return heugcd(f, g)
#    2197
#    2198     def _gcd_QQ(self, g):
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/heuristicgcd.py in heugcd(f, g)
#      78                 h, cff, cfg = domain.cofactors(ff, gg)
#      79             else:
# ---> 80                 h, cff, cfg = heugcd(ff, gg)
#      81
#      82             h = _gcd_interpolate(h, x, ring)
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/heuristicgcd.py in heugcd(f, g)
#      83             h = h.primitive()[1]
#      84
# ---> 85             cff_, r = f.div(h)
#      86
#      87             if not r:
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/rings.py in div(self, fv)
#    1465             divoccurred = 0
#    1466             while i < s and divoccurred == 0:
# -> 1467                 expv = p.leading_expv()
#    1468                 term = term_div((expv, p[expv]), (expvs[i], fv[i][expvs[i]]))
#    1469                 if term is not None:
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/rings.py in leading_expv(self)
#    1697         """
#    1698         if self:
# -> 1699             return self.ring.leading_expv(self)
#    1700         else:
#    1701             return None
#
# KeyboardInterrupt:
